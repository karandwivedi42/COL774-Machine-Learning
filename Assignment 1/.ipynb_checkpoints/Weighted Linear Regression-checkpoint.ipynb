# %% [markdown]
# #### Locally Weighted Linear Regression
#
# Most of the code is same from last time. Only the loss and grad_loss functions are different.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.animation as animation
# %matplotlib notebook

# %% [markdown]
# We begin by loading the data and estimating the graph using pandas.

# %%
data = pd.concat([pd.read_table('q3x.dat', names = ['x']),pd.read_table('q3y.dat', names = ['y'])], axis=1)
data.plot(kind='scatter', x='x', y='y')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Hmm.
#
# Normalize the inputs and store it in numpy array. Finally Concatenate 1 to the inputs as a simple way to introduce the bias term.

# %%
inputs = data.values[:,0:1]
targets = data.values[:,1:2]

inputs_mean = np.mean(inputs, axis=0)
inputs_std = np.std(inputs,axis=0)
inputs = (inputs - inputs_mean)/(inputs_std + np.finfo(float).eps)
inputs = np.concatenate((np.ones((inputs.shape[0],1)),inputs),axis=1)

# %% [markdown]
# We define the loss, gradLoss functions. We also define the lin. regression loop.

# %%
def weighted_l2loss(inputs,targets,weights,W):
    p = np.dot(inputs,weights)-targets
    return (np.dot(p.T,np.dot(W,p))/(2*inputs.shape[0]))[0][0]

def l2loss(inputs,targets,weights,W):
    if W is None:
        p = np.dot(inputs,weights)-targets
        return (np.dot(p.T,p)/(2*inputs.shape[0]))[0][0]
    else:
        return weighted_l2loss(inputs,targets,weights,W)

def weighted_l2error(inputs, targets, weights,W):
    return np.dot(np.dot(inputs.T,W), ((np.dot(inputs,weights)-targets))).mean(axis=1, keepdims=True)

def l2error(inputs, targets, weights,W):
    if W is None:
        return np.dot(inputs.T, ((np.dot(inputs,weights)-targets))).mean(axis=1, keepdims=True)
    else:
        return weighted_l2error(inputs,targets,weights,W)

def lin_reg_loop(learning_rate, stopping_df_dx,W=None):
    animation_losses = []
    weights = np.zeros((inputs.shape[1],1))
    while True:
        loss = l2loss(inputs, targets, weights,W)
        df_dx = l2error(inputs, targets, weights,W)    
        animation_losses.append([weights[0][0], weights[1][0], loss])
        weights = weights - learning_rate*df_dx
        if (np.linalg.norm(df_dx) < stopping_df_dx):
            animation_losses.append([weights[0][0], weights[1][0], loss])
            break

    print ('Line: y = ' , weights[1][0], ' x_norm + ', weights[0][0])
    print('Final loss:', loss)
    print('Learning Rate: ', learning_rate)
    print('Stopping Criteria: df/dx <', stopping_df_dx)
    print('Num iterations: ', len(animation_losses))

    return weights, np.array(animation_losses).T

# %% [markdown]
# First, let's try to find a linear fit using simple unweighted regression.

# %%
weights, data = lin_reg_loop(learning_rate=0.013, stopping_df_dx=1e-10)

fig = plt.figure()
plt.plot(inputs, inputs*weights[1] + weights[0])
plt.scatter(inputs[:,1:2],targets,c='g')
plt.show()
# Out:
# Line: y =  0.835188895313  x_norm +  1.03127983079
# Final loss: 0.333364453435
# Learning Rate:  0.013
# Stopping Criteria: df/dx < 1e-10
# Num iterations:  26
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Of course, it doesn't fit.
#
# Now we make a function that returns the W (Weights) diagonal matrix for given input and bandwidth. Also, we choose the test points uniformly from the same range as training data.
#
# We plot the training data in green points, and test data in blue points.

# %%
def get_W(x,Tau):
    return np.diag(np.exp(-((inputs[:,1] - x)**2)/(2*Tau*Tau)))

test_inputs = np.linspace(-2,2,num=100)
test_results = np.empty_like(test_inputs)

for t,x in enumerate(test_inputs):
    weights, data = lin_reg_loop(learning_rate=0.001, stopping_df_dx=0.01,W=get_W(x,0.8))
    test_results[t] = weights[0][0] + weights[1][0]*x


fig = plt.figure()
plt.scatter(inputs[:,1:2],targets,c='g')
plt.scatter(test_inputs,test_results,c='b')

plt.show()
# Out:
# Line: y =  2.22308677343  x_norm +  2.23143687366
# Final loss: 0.00935048869073
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  3260
# Line: y =  2.22447745895  x_norm +  2.23320610577
# Final loss: 0.0101775782446
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  3033
# Line: y =  2.22481894875  x_norm +  2.23368164456
# Final loss: 0.0110891145817
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  2825
# Line: y =  2.22405489303  x_norm +  2.23283071524
# Final loss: 0.012095514747
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  2634
# Line: y =  2.22212594399  x_norm +  2.23062094883
# Final loss: 0.0132082314698
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  2458
# Line: y =  2.21898222303  x_norm +  2.22703685115
# Final loss: 0.0144397421287
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  2297
# Line: y =  2.214553355  x_norm +  2.22204087795
# Final loss: 0.0158035161295
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  2148
# Line: y =  2.2087790947  x_norm +  2.21561377149
# Final loss: 0.0173139387084
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  2010
# Line: y =  2.2016101289  x_norm +  2.20775495874
# Final loss: 0.0189862011797
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  1884
# Line: y =  2.19297139389  x_norm +  2.1984364418
# Final loss: 0.0208361539133
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  1767
# Line: y =  2.18279954145  x_norm +  2.18765058079
# Final loss: 0.022880099856
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  1658
# Line: y =  2.17104393362  x_norm +  2.17541048382
# Final loss: 0.0251345431267
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  1558
# Line: y =  2.15763573785  x_norm +  2.16171226741
# Final loss: 0.0276158893242
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  1465
# Line: y =  2.14252016183  x_norm +  2.14657437023
# Final loss: 0.0303400816504
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  1379
# Line: y =  2.12563817449  x_norm +  2.13001527695
# Final loss: 0.0333221916681
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  1299
# Line: y =  2.10694019202  x_norm +  2.11206945582
# Final loss: 0.036575954676
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  1225
# Line: y =  2.08637398273  x_norm +  2.09277294654
# Final loss: 0.0401132641116
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  1156
# Line: y =  2.06389199549  x_norm +  2.07217162912
# Final loss: 0.0439436261182
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  1091
# Line: y =  2.03946577008  x_norm +  2.050336378
# Final loss: 0.048073587327
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  1031
# Line: y =  2.01306036565  x_norm +  2.02733393231
# Final loss: 0.0525061568637
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  975
# Line: y =  1.98465533289  x_norm +  2.00324934053
# Final loss: 0.057240226583
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  923
# Line: y =  1.95423218715  x_norm +  1.97817157448
# Final loss: 0.0622700211729
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  874
# Line: y =  1.92178902729  x_norm +  1.95220792365
# Final loss: 0.0675845910984
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  828
# Line: y =  1.88733472943  x_norm +  1.92547645929
# Final loss: 0.0731673789484
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  785
# Line: y =  1.85088979561  x_norm +  1.8981055906
# Final loss: 0.0789958795661
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  745
# Line: y =  1.81247988466  x_norm +  1.87022659509
# Final loss: 0.0850414200666
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  707
# Line: y =  1.77215786384  x_norm +  1.84199325343
# Final loss: 0.0912690773798
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  672
# Line: y =  1.72996823883  x_norm +  1.81354679348
# Final loss: 0.0976377650847
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  638
# Line: y =  1.68599825653  x_norm +  1.78506146103
# Final loss: 0.104100485248
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  607
# Line: y =  1.64032689308  x_norm +  1.75669612013
# Final loss: 0.110604781274
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  578
# Line: y =  1.59304631823  x_norm +  1.72861295225
# Final loss: 0.117093371254
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  550
# Line: y =  1.54427672637  x_norm +  1.70098775928
# Final loss: 0.123504968681
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  524
# Line: y =  1.49413548714  x_norm +  1.67398266116
# Final loss: 0.12977528301
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  499
# Line: y =  1.44276683134  x_norm +  1.64776870308
# Final loss: 0.135838165548
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  476
# Line: y =  1.39030969701  x_norm +  1.62249936262
# Final loss: 0.141626887879
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  454
# Line: y =  1.33692787602  x_norm +  1.59833215789
# Final loss: 0.147075501135
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  434
# Line: y =  1.28277656882  x_norm +  1.57540334554
# Final loss: 0.152120250538
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  415
# Line: y =  1.22802477384  x_norm +  1.55384337193
# Final loss: 0.156700984683
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  397
# Line: y =  1.17284557388  x_norm +  1.53376919273
# Final loss: 0.160762523181
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  380
# Line: y =  1.1174143556  x_norm +  1.51528275022
# Final loss: 0.164255930584
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  364
# Line: y =  1.06190702189  x_norm +  1.49846971469
# Final loss: 0.167139653278
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  349
# Line: y =  1.00649824456  x_norm +  1.48339851691
# Final loss: 0.169380479899
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  335
# Line: y =  0.951368821883  x_norm +  1.47012341983
# Final loss: 0.170954291652
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  323
# Line: y =  0.896668239146  x_norm +  1.45866885341
# Final loss: 0.171846584103
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  311
# Line: y =  0.842566899319  x_norm +  1.44905285415
# Final loss: 0.172052730615
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  300
# Line: y =  0.789210039004  x_norm +  1.44126891894
# Final loss: 0.171578002879
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  289
# Line: y =  0.736763180316  x_norm +  1.43530071909
# Final loss: 0.170437332292
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  280
# Line: y =  0.685345755176  x_norm +  1.4311054504
# Final loss: 0.168654847334
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  271
# Line: y =  0.635087225979  x_norm +  1.42863026303
# Final loss: 0.166263183862
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  262
# Line: y =  0.586118609999  x_norm +  1.42780726731
# Final loss: 0.163302616198
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  254
# Line: y =  0.538525042619  x_norm +  1.42855382365
# Final loss: 0.159820039325
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  244
# Line: y =  0.492428033501  x_norm +  1.43077518166
# Final loss: 0.155867821647
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  233
# Line: y =  0.447887252981  x_norm +  1.43436815017
# Final loss: 0.15150259808
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  214
# Line: y =  0.405018252457  x_norm +  1.43915493103
# Final loss: 0.146784001356
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  167
# Line: y =  0.364484525803  x_norm +  1.44500477686
# Final loss: 0.141773419004
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  198
# Line: y =  0.325088644986  x_norm +  1.45198085673
# Final loss: 0.13653274169
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  233
# Line: y =  0.287522008096  x_norm +  1.45983054934
# Final loss: 0.13112321588
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  254
# Line: y =  0.251813150461  x_norm +  1.46843151465
# Final loss: 0.125604350088
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  272
# Line: y =  0.218000802868  x_norm +  1.47764643949
# Final loss: 0.120032949314
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  289
# Line: y =  0.186121517062  x_norm +  1.48733325395
# Final loss: 0.114462266311
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  305
# Line: y =  0.156192730288  x_norm +  1.49735602875
# Final loss: 0.108941288791
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  321
# Line: y =  0.128224848374  x_norm +  1.50758128493
# Final loss: 0.103514173002
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  338
# Line: y =  0.102239101325  x_norm +  1.51786758732
# Final loss: 0.0982198236061
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  355
# Line: y =  0.0782269535284  x_norm +  1.5280919623
# Final loss: 0.0930916103541
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  374
# Line: y =  0.0562081248072  x_norm +  1.53811314572
# Final loss: 0.0881572352142
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  393
# Line: y =  0.0361739772064  x_norm +  1.5478098884
# Final loss: 0.0834387161506
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  413
# Line: y =  0.0181125844037  x_norm +  1.55706589
# Final loss: 0.0789525006138
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  435
# Line: y =  0.00202446509527  x_norm +  1.56575784234
# Final loss: 0.0747096854664
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  458
# Line: y =  -0.012100982191  x_norm +  1.57377339603
# Final loss: 0.0707163253211
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  482
# Line: y =  -0.024284918309  x_norm +  1.58101221483
# Final loss: 0.066973822355
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  508
# Line: y =  -0.0345436378582  x_norm +  1.58737394456
# Final loss: 0.0634793811852
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  536
# Line: y =  -0.0428963017834  x_norm +  1.59276457139
# Final loss: 0.060226508258
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  566
# Line: y =  -0.0493576338239  x_norm +  1.59709018038
# Final loss: 0.0572055453692
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  597
# Line: y =  -0.0539673545723  x_norm +  1.60028366044
# Final loss: 0.0544042155853
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  631
# Line: y =  -0.0567459472213  x_norm +  1.60226547538
# Final loss: 0.0518081825111
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  667
# Line: y =  -0.0577314715124  x_norm +  1.60297703445
# Final loss: 0.0494015890696
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  706
# Line: y =  -0.0569506230368  x_norm +  1.60235398643
# Final loss: 0.0471675840886
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  747
# Line: y =  -0.0544474902623  x_norm +  1.6003535807
# Final loss: 0.0450888095715
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  791
# Line: y =  -0.0502551053719  x_norm +  1.59692737091
# Final loss: 0.0431478559014
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  837
# Line: y =  -0.0444376479167  x_norm +  1.59206319181
# Final loss: 0.0413276601218
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  888
# Line: y =  -0.0370204168713  x_norm +  1.58571493931
# Final loss: 0.039611867892
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  941
# Line: y =  -0.0280735207055  x_norm +  1.57788719997
# Final loss: 0.0379851177213
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  999
# Line: y =  -0.0176354436476  x_norm +  1.56855713407
# Final loss: 0.0364332904628
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  1060
# Line: y =  -0.00577497375559  x_norm +  1.55773860428
# Final loss: 0.0349436810018
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  1126
# Line: y =  0.00745692978551  x_norm +  1.54543167396
# Final loss: 0.0335051292818
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  1196
# Line: y =  0.0219932829646  x_norm +  1.5316584445
# Final loss: 0.0321080854582
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  1271
# Line: y =  0.0377716847046  x_norm +  1.51644095103
# Final loss: 0.0307446329514
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  1351
# Line: y =  0.0547145387992  x_norm +  1.49982286467
# Final loss: 0.0294084603187
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  1438
# Line: y =  0.0727692901521  x_norm +  1.48182454435
# Final loss: 0.0280948025584
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  1530
# Line: y =  0.0918621766528  x_norm +  1.46249435247
# Final loss: 0.026800336067
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  1628
# Line: y =  0.111918702843  x_norm +  1.4418859876
# Final loss: 0.0255230567252
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  1733
# Line: y =  0.132864005871  x_norm +  1.42005789004
# Final loss: 0.0242621347186
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  1846
# Line: y =  0.154636191104  x_norm +  1.39705738307
# Final loss: 0.0230177575773
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  1966
# Line: y =  0.177154250834  x_norm +  1.3729578792
# Final loss: 0.0217909585731
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  2095
# Line: y =  0.200357320038  x_norm +  1.34781273138
# Final loss: 0.0205834541458
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  2232
# Line: y =  0.224166354509  x_norm +  1.32170026258
# Final loss: 0.0193974724342
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  2379
# Line: y =  0.248529301193  x_norm +  1.29466963759
# Final loss: 0.0182356022406
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  2534
# Line: y =  0.273363972886  x_norm +  1.2668093354
# Final loss: 0.0171006370464
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  2700
# Line: y =  0.298609280708  x_norm +  1.23818526956
# Final loss: 0.01599544982
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  2877
# Line: y =  0.324218723426  x_norm +  1.20884780084
# Final loss: 0.0149228746497
# Learning Rate:  0.001
# Stopping Criteria: df/dx < 0.01
# Num iterations:  3063
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Now we can change the value of bandwidth to see its effect on the output.
